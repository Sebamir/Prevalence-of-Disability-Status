# %%
import pandas as pd

# Cargar el dataframe exportado desde SQL
df = pd.read_csv("Correlation_table.csv")

# Calcular correlación entre indicadores
correlation_matrix = df.drop(columns=["locationdesc", "year"]).corr()

print(correlation_matrix)

# Visualizar
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()
# Out:
#                     self_care  any_disability   hearing    vision  cognitive  \
# self_care            1.000000        0.866296  0.519218  0.748811   0.788699
# any_disability       0.866296        1.000000  0.715497  0.785587   0.933515
# hearing              0.519218        0.715497  1.000000  0.452121   0.605754
# vision               0.748811        0.785587  0.452121  1.000000   0.612284
# cognitive            0.788699        0.933515  0.605754  0.612284   1.000000
# no_disability       -0.866296       -1.000000 -0.715497 -0.785587  -0.933515
# mobility             0.929620        0.896828  0.563208  0.748333   0.781595
# independent_living   0.885299        0.911119  0.589686  0.690637   0.880564
#
#                     no_disability  mobility  independent_living
# self_care               -0.866296  0.929620            0.885299
# any_disability          -1.000000  0.896828            0.911119
# hearing                 -0.715497  0.563208            0.589686
# vision                  -0.785587  0.748333            0.690637
# cognitive               -0.933515  0.781595            0.880564
# no_disability            1.000000 -0.896828           -0.911119
# mobility                -0.896828  1.000000            0.876068
# independent_living      -0.911119  0.876068            1.000000
